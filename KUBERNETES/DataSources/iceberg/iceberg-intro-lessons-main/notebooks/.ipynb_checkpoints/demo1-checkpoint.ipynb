# %%
import pyspark
import pyspark
from pyspark.sql import SparkSession
import os

## DEFINE SENSITIVE VARIABLES
NESSIE_URI = "http://nessie:19120/api/v1"
MINIO_ACCESS_KEY = "0zWsID7Fb2UrNyX0OkBA"
MINIO_SECRET_KEY = "nBoYv4NG0z6PNffzhjLjgAfumDjRfvJVGCRgfZfY"

conf = (
    pyspark.SparkConf()
        .setAppName('app_name')
                #packages
        .set('spark.jars.packages', 'org.apache.iceberg:iceberg-spark-runtime-3.3_2.12:1.3.1,org.projectnessie.nessie-integrations:nessie-spark-extensions-3.3_2.12:0.67.0,software.amazon.awssdk:bundle:2.17.178,software.amazon.awssdk:url-connection-client:2.17.178')
                #SQL Extensions
        .set('spark.sql.extensions', 'org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions,org.projectnessie.spark.extensions.NessieSparkSessionExtensions')
                #Configuring Catalog
        .set('spark.sql.catalog.nessie', 'org.apache.iceberg.spark.SparkCatalog')
        .set('spark.sql.catalog.nessie.uri', NESSIE_URI)
        .set('spark.sql.catalog.nessie.ref', 'main')
        .set('spark.sql.catalog.nessie.authentication.type', 'NONE')
        .set('spark.sql.catalog.nessie.catalog-impl', 'org.apache.iceberg.nessie.NessieCatalog')
        .set('spark.sql.catalog.nessie.warehouse', 's3a://warehouse')
        .set('spark.sql.catalog.nessie.s3.endpoint', 'http://minio:9000')
        .set('spark.sql.catalog.nessie.io-impl', 'org.apache.iceberg.aws.s3.S3FileIO')
                #MINIO CREDENTIALS
        .set('spark.hadoop.fs.s3a.access.key', MINIO_ACCESS_KEY)
        .set('spark.hadoop.fs.s3a.secret.key', MINIO_SECRET_KEY)
        .set("spark.extraListeners", "datahub.spark.DatahubSparkListener")
        .set("spark.datahub.rest.server","http://datahub-datahub-gms:8080")
        .set("spark.datahub.rest.token","<DATAHUB_TOKEN>")
        .set("spark.datahub.platformInstance","local-iceberg")
        .set("spark.jars.packages","io.acryl:datahub-spark-lineage:0.13.1,"
                "org.apache.iceberg:iceberg-spark-runtime-3.3_2.12:1.3.1",
                "org.projectnessie.nessie-integrations:nessie-spark-extensions-3.3_2.12:0.67.0",
                "software.amazon.awssdk:bundle:2.17.178",
                "software.amazon.awssdk:url-connection-client:2.17.178"
)
)

## Start Spark Session
spark = SparkSession.builder.config(conf=conf).getOrCreate()
print("Spark Running")

## LOAD A CSV INTO AN SQL VIEW
csv_df = spark.read.format("csv").option("header", "true").load("../datasets/df_open_2023.csv")
csv_df.createOrReplaceTempView("csv_open_2023")

## CREATE AN ICEBERG TABLE FROM THE SQL VIEW
spark.sql("CREATE TABLE IF NOT EXISTS nessie.df_open_2023_lesson3 USING iceberg PARTITIONED BY (countryOfOriginCode) AS SELECT * FROM csv_open_2023 ORDER BY countryOfOriginCode;").show()

## ALTER PARTITIONING BASED ON TRUNCATE FIRST LETTER OF firstName
spark.sql("ALTER TABLE nessie.df_open_2023_lesson3 ADD PARTITION FIELD truncate(1, firstName)").show()

## REWRITE ALL THE DATA SO IT ALL USES UPDATED PARTITONING
spark.sql("CALL nessie.system.rewrite_data_files('df_open_2023_lesson3')").show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 34
#       8 MINIO_ACCESS_KEY = "0zWsID7Fb2UrNyX0OkBA"
#       9 MINIO_SECRET_KEY = "nBoYv4NG0z6PNffzhjLjgAfumDjRfvJVGCRgfZfY"
#      11 conf = (
#      12         pyspark.SparkConf()
#      13                 .setAppName('app_name')
#      14                         #packages
#      15                 .set('spark.jars.packages', 'org.apache.iceberg:iceberg-spark-runtime-3.3_2.12:1.3.1,org.projectnessie.nessie-integrations:nessie-spark-extensions-3.3_2.12:0.67.0,software.amazon.awssdk:bundle:2.17.178,software.amazon.awssdk:url-connection-client:2.17.178')
#      16                         #SQL Extensions
#      17                 .set('spark.sql.extensions', 'org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions,org.projectnessie.spark.extensions.NessieSparkSessionExtensions')
#      18                         #Configuring Catalog
#      19                 .set('spark.sql.catalog.nessie', 'org.apache.iceberg.spark.SparkCatalog')
#      20                 .set('spark.sql.catalog.nessie.uri', NESSIE_URI)
#      21                 .set('spark.sql.catalog.nessie.ref', 'main')
#      22                 .set('spark.sql.catalog.nessie.authentication.type', 'NONE')
#      23                 .set('spark.sql.catalog.nessie.catalog-impl', 'org.apache.iceberg.nessie.NessieCatalog')
#      24                 .set('spark.sql.catalog.nessie.warehouse', 's3a://warehouse')
#      25                 .set('spark.sql.catalog.nessie.s3.endpoint', 'http://minio:9000')
#      26                 .set('spark.sql.catalog.nessie.io-impl', 'org.apache.iceberg.aws.s3.S3FileIO')
#      27                         #MINIO CREDENTIALS
#      28                 .set('spark.hadoop.fs.s3a.access.key', MINIO_ACCESS_KEY)
#      29                 .set('spark.hadoop.fs.s3a.secret.key', MINIO_SECRET_KEY)
#      30                 .set("spark.extraListeners", "datahub.spark.DatahubSparkListener")
#      31                 .set("spark.datahub.rest.server","http://datahub-datahub-gms:8080")
#      32                 .set("spark.datahub.rest.token","<DATAHUB_TOKEN>")
#      33                 .set("spark.datahub.platformInstance","local-iceberg")
# ---> 34                 .set("spark.jars.packages","io.acryl:datahub-spark-lineage:0.13.1,"
#      35                         "org.apache.iceberg:iceberg-spark-runtime-3.3_2.12:1.3.1",
#      36                         "org.projectnessie.nessie-integrations:nessie-spark-extensions-3.3_2.12:0.67.0",
#      37                         "software.amazon.awssdk:bundle:2.17.178",
#      38                         "software.amazon.awssdk:url-connection-client:2.17.178"
#      39 )
#      40 )
#      42 ## Start Spark Session
#      43 spark = SparkSession.builder.config(conf=conf).getOrCreate()
#
# TypeError: SparkConf.set() takes 3 positional arguments but 6 were given
